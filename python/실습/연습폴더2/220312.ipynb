# %%
a = 10
a
def func_1():
    return "test"

b = func_1()
b
def func_2(a, b):
    return a+b

c = func_2(3, 2)
c
x = ""

if x:
    print("데이터가 존재")
else:
    print("데이터가 존재X")
for i in range(0, 10, 3):
    print(i)
_list = [7,8,9,1,2]

for i in _list:
    print(i)
a = [1,2,3,4,5,6]

for i in a:
    for j in a:
        if (i+j)%5 == 0:
            print(i, j) 
sum = 0
x = -1

while x < 11:
    x += 1
    sum += x

print(sum)
sum = 0
for i in range(1, 100, 1):
    sum += i
    if sum >= 700:
        print(i)
        break
    else:
        continue
for i in range(1, 10, 1):
    if i < 3:
        continue
    print(i)
import yfinance as yf
yf.download('AAPL', start= '2019-01-01')
data = yf.download(["AAPL", "TSLA", "AMZN", "CPNG"], start="2019-01-01")
data
data['Close']['AAPL']
aapl = yf.Ticker("AAPL")
aapl.dividends
aapl.splits
aapl.recommendations
aapl.info
aapl.history(period='max')
cpng = yf.Ticker("CPNG")
import pandas as pd
result = cpng.info
pd.Series(result)
cpng.history(start = "2022-01-01")
import pyupbit as upbit
upbit.get_tickers(fiat='KRW')
upbit.get_current_price(["KRW-BTC", "KRW-ETH"])
ticker = 'KRW-BTC'
interval = "week"
to = "2022-01-01 00:00"
count = 100
upbit.get_ohlcv(ticker=ticker, interval=interval)
3시 50분 프리하게 데이터 튜닝
주식, 코인 데이터를 가지고 데이터의 갯수 1000개 선택
데이터를 csv로 변환
csv를 DB 삽입
mysql query데이터를 받아오는데(Module 생성, Class로 구현)
주식의 기준 -> 시가, 종가, 고가, 저가 소수점 2번째 자리까지 유지 반올림.
코인의 기준 -> 볼륨 소수점 2번째 자리까지 유지 반올림.
주식 기준 Nan 값 존재 시작되는 지점의 시가로 변환
컬럼을 하나 추가 등락폭(종가-시가의 값)을 삽입
컬럼을 하나 추가 (등락폭/시가 * 100) 퍼센트를 삽입
데이터의 시각화 -> 시가/ 종가/ 등락폭 / 볼륨 그래프 4개를 subplot 나눠서 4개 표현
import yfinance as yf
import pandas as pd
import mod_sql
apple = yf.Ticker("AAPL")
result = apple.history(period="max")
result.to_csv("apple.csv")
_sql = """
        CREATE TABLE apple_test2(
            Date varchar(32) primary key, 
            Open float, 
            High float, 
            Low float, 
            Close float
        )
    """
_db = mod_sql.Database()
_db.execute(_sql)
result.index
list(result.Open)
result
_sql2 = """
        INSERT INTO apple_test2 values (
            # %s, %s, %s, %s, %s
        )
    """
for i in range(100):
    _db.execute(_sql2, 
    [result.index[i],
    result.Open[i],
    result.High[i],
    result.Low[i],
    result.Close[i]])

_db.commit()
_sql = """
        SELECT * FROM apple
    """
result = _db.executeAll(_sql)

_df = pd.DataFrame(result)
_df
_df = _df.round(2)
_df
_df.isna().sum()
_df.fillna("bfill")
_df["등락폭"] = _df["Close"] - _df["Open"]
_df
_df["등락율"] = _df["등락폭"] / _df["Open"] * 100
_df
import matplotlib.pyplot as plt
plt.subplot(2,2,1)
plt.plot(_df["Open"])
plt.subplot(2,2,2)
plt.plot(_df["Close"])
plt.subplot(2,2,3)
plt.plot(_df["등락폭"])
plt.subplot(2,2,4)
plt.plot(_df["등락율"])
plt.show()
